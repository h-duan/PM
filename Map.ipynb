# %%
import cartopy.crs as ccrs
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# /lustre/project/TGABI/GEOS-Chem/ExtData/HEMCO/MEIC_v1_4_SAPRC99_GC
#
# ![截屏2024-07-24 下午4.47.59.png](attachment:591ef1ec-7ee9-4ee3-8b3d-994fd87812c4.png)

# %%
# Map limiting the area to the Greater Bay Area


# Create a GeoAxes instance
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(1, 1, 1, projection=ccrs.PlateCarree())

# Set the extent of the map to the Greater Bay Area coordinates
extent = [112.5, 115.0, 21.5, 23.5]  # [min_lon, max_lon, min_lat, max_lat]
ax.set_extent(extent, crs=ccrs.PlateCarree())

# Add coastlines and borders
ax.coastlines(resolution='10m', color='black', linewidth=1)
ax.add_feature(ccrs.cartopy.feature.BORDERS, linestyle=':', linewidth=0.5)


# Plot the location as a dot
lat = 22 + 16/60 + 22/3600  # Convert degrees, minutes, and seconds to decimal degrees
lon = 113 + 31/60 + 46/3600
ax.scatter(lon, lat, color='red', marker='o', s=50, transform=ccrs.PlateCarree())
ax.scatter(113.27,23.16,color='blue',marker='o',s=30,transform=ccrs.PlateCarree(),label='Baiyun')

# from Baidu yun net
#


# Add a title
ax.set_title('Map of Greater Bay Area')

# Show the plot
plt.show()

# %% [markdown]
# ![截屏2024-07-10 下午4.24.09.png](attachment:41f0c692-dd64-4eef-9c51-e176be4a8acc.png)

# %% [markdown]
# ![截屏2024-07-10 下午4.30.51.png](attachment:16535b48-bcaf-4e1f-89ea-775a98c17811.png)

# %%
# read in the lat and lon for the 10 cities in GBA

path = "/Users/hrd/Documents/data/全国空气质量/_站点列表/站点列表-2017.12.01起.csv"
site = pd.read_csv(path)

# read the site name (a), lon (b) and lat (c)
a = site.iloc[:,2]
b = site.iloc[:,3]
c = site.iloc[:,4]

lon=[]
lat = []

for i in range(len(a)):
    if a[i] == '广州' or a[i] == '深圳' or a[i] == '珠海' or a[i] == '佛山' or a[i] == '中山' or a[i] == '江门' or a[i] == '东莞'or a[i] == '惠州' or a[i] == '肇庆':
        lon.append(b[i])
        lat.append(c[i])


# omit the nan value
lon.pop(2)
lat.pop(2)
# Out:
# nan

# %%
# for MEE (Baiduyun) data
# Guangzhou  (10)
# Shenzhen   (11)
# Zhuhai     (4)
# Foshan     (8)
# Zhaongshan (4)
# Jiangmen   (4)
# Dongguan   (5)
# Huizhou    (5)
# Zhaoqing   (4)

# Create a GeoAxes instance
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(1, 1, 1, projection=ccrs.PlateCarree())

# Set the extent of the map to the Greater Bay Area coordinates
extent = [112.5, 115.0, 21.5, 23.5]  # [min_lon, max_lon, min_lat, max_lat]
ax.set_extent(extent, crs=ccrs.PlateCarree())

# Add coastlines and borders
ax.coastlines(resolution='10m', color='black', linewidth=1)
ax.add_feature(ccrs.cartopy.feature.BORDERS, linestyle=':', linewidth=0.5)


# Plot the location as a dot
#ax.scatter(113.235,23.1422, color='red', marker='o', s=80, transform=ccrs.PlateCarree())
for i in range(len(lon)):
    ax.scatter(lon[i],lat[i], color='blue', marker='o', s=50, transform=ccrs.PlateCarree())

# from Baidu yun net
#


# Add a title
ax.set_title('Baidu yun')

# Show the plot
plt.show()

# %%
# Create a GeoAxes instance
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(1, 1, 1, projection=ccrs.PlateCarree())

# Set the extent of the map to the Greater Bay Area coordinates
extent = [112.5, 115.0, 21.5, 23.5]  # [min_lon, max_lon, min_lat, max_lat]
ax.set_extent(extent, crs=ccrs.PlateCarree())

# Add coastlines and borders
ax.coastlines(resolution='10m', color='black', linewidth=1)
ax.add_feature(ccrs.cartopy.feature.BORDERS, linestyle=':', linewidth=0.5)


# Plot the location as a dot
#ax.scatter(113.235,23.1422, color='red', marker='o', s=80, transform=ccrs.PlateCarree())
for i in range(len(lon)):
    ax.scatter(lon[i],lat[i], color='blue', marker='o', s=50, transform=ccrs.PlateCarree())
ax.scatter(113.235,23.1422, color='blue', marker='o', s=50, transform=ccrs.PlateCarree(),label='baidu yun')

ax.scatter(113.27,23.16,color='red',marker='o',s=65,transform=ccrs.PlateCarree(),label='Baiyun')
ax.scatter(113.144,23.0467,color='orange',marker='o',s=60,transform=ccrs.PlateCarree(),label='NH')
ax.scatter(113.738,22.95,color='orange',marker='o',s=60,transform=ccrs.PlateCarree(),label='DG')
ax.scatter(113+35/60,22.755,color='orange',marker='o',s=60,transform=ccrs.PlateCarree(),label='NS')

# from Baidu yun net
#


# Add a title
ax.set_title('sites')
gridlines = ax.gridlines(draw_labels=True, color='gray', linestyle='--')
gridlines.xlabels_top = False
gridlines.ylabels_right = False

ax.legend()

# Show the plot
plt.show()
# Out:
# /Users/hrd/anaconda3/lib/python3.11/site-packages/cartopy/mpl/gridliner.py:451: UserWarning: The .xlabels_top attribute is deprecated. Please use .top_labels to toggle visibility instead.
#   warnings.warn('The .xlabels_top attribute is deprecated. Please '
# /Users/hrd/anaconda3/lib/python3.11/site-packages/cartopy/mpl/gridliner.py:487: UserWarning: The .ylabels_right attribute is deprecated. Please use .right_labels to toggle visibility instead.
#   warnings.warn('The .ylabels_right attribute is deprecated. Please '

# %%
# Create a GeoAxes instance
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(1, 1, 1, projection=ccrs.PlateCarree())

# Set the extent of the map to the Greater Bay Area coordinates
extent = [113, 114.25, 22.25, 23.25]  # [min_lon, max_lon, min_lat, max_lat]
ax.set_extent(extent, crs=ccrs.PlateCarree())

# Add coastlines and borders
ax.coastlines(resolution='10m', color='black', linewidth=1)
ax.add_feature(ccrs.cartopy.feature.BORDERS, linestyle=':', linewidth=0.5)


# Plot the location as a dot
#ax.scatter(113.235,23.1422, color='red', marker='o', s=80, transform=ccrs.PlateCarree())
for i in range(len(lon)):
    ax.scatter(lon[i],lat[i], color='blue', marker='o', s=50, transform=ccrs.PlateCarree())
ax.scatter(113.27,23.16,color='red',marker='o',s=50,transform=ccrs.PlateCarree(),label='Baiyun')
ax.scatter(113.144,23.0467,color='orange',marker='o',s=50,transform=ccrs.PlateCarree(),label='NH')
ax.scatter(113.738,22.95,color='orange',marker='o',s=50,transform=ccrs.PlateCarree(),label='DG')
ax.scatter(113+36.25/60,22.75,color='orange',marker='o',s=50,transform=ccrs.PlateCarree(),label='NS')

# from Baidu yun net
#


# Add a title
ax.set_title('sites')
gridlines = ax.gridlines(draw_labels=True, color='gray', linestyle='--')
gridlines.xlabels_top = False
gridlines.ylabels_right = False

#ax.legend()

# Show the plot
plt.show()
# Out:
# /Users/hrd/anaconda3/lib/python3.11/site-packages/cartopy/mpl/gridliner.py:451: UserWarning: The .xlabels_top attribute is deprecated. Please use .top_labels to toggle visibility instead.
#   warnings.warn('The .xlabels_top attribute is deprecated. Please '
# /Users/hrd/anaconda3/lib/python3.11/site-packages/cartopy/mpl/gridliner.py:487: UserWarning: The .ylabels_right attribute is deprecated. Please use .right_labels to toggle visibility instead.
#   warnings.warn('The .ylabels_right attribute is deprecated. Please '

# %%
# shp. shengfen xian
